# %%
import os
# Change native directory to root
os.chdir(os.path.dirname(os.getcwd()))

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb

features = ['Month', 'Hour', 'hour_x', 'hour_y', 'month_x', 'month_y',
'net_target-1', 'diffuse_solar_radiation+1', 'relative_humidity+1', 'drybulb_temp+1']
target = 'net_target'
qts = np.concatenate([[0.001],np.arange(0.05,0.951,0.05),[0.999]])
# Out:
# /Users/evgenygenov/miniforge3/envs/conformal/lib/python3.8/site-packages/dask/dataframe/backends.py:187: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# /Users/evgenygenov/miniforge3/envs/conformal/lib/python3.8/site-packages/dask/dataframe/backends.py:187: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# /Users/evgenygenov/miniforge3/envs/conformal/lib/python3.8/site-packages/dask/dataframe/backends.py:187: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %%
data_train = pd.read_csv('data/extra_train.csv', index_col=0)
data_test = pd.read_csv('data/extra_test.csv', index_col=0)
data_train
# Out:
#        Month  Hour  Day Type  cons_target-1  Solar Generation [W/kW]  \
# 2        8.0   0.0       2.0       0.116313                      0.0
# 3        8.0   1.0       2.0       0.106422                      0.0
# 4        8.0   2.0       2.0       0.109127                      0.0
# 5        8.0   3.0       2.0       0.107621                      0.0
# 6        8.0   4.0       2.0       0.120207                      0.0
# ...      ...   ...       ...            ...                      ...
# 43653    7.0  19.0       7.0       0.092567                      0.0
# 43654    7.0  20.0       7.0       0.144716                      0.0
# 43655    7.0  21.0       7.0       0.335914                      0.0
# 43656    7.0  22.0       7.0       0.223369                      0.0
# 43657    7.0  23.0       7.0       0.272052                      0.0
#
#        Outdoor Drybulb Temperature [C]  Relative Humidity [%]  \
# 2                                 19.4                   87.0
# 3                                 19.4                   87.0
# 4                                 19.4                   90.0
# 5                                 18.9                   90.0
# 6                                 18.3                   93.0
# ...                                ...                    ...
# 43653                             18.3                   90.0
# 43654                             18.9                   87.0
# 43655                             19.4                   84.0
# 43656                             18.9                   90.0
# 43657                             20.5                   76.0
#
#        Diffuse Solar Radiation [W/m2]  Direct Solar Radiation [W/m2]  \
# 2                                 0.0                            0.0
# 3                                 0.0                            0.0
# 4                                 0.0                            0.0
# 5                                 0.0                            0.0
# 6                                 0.0                            0.0
# ...                               ...                            ...
# 43653                             0.0                            0.0
# 43654                             0.0                            0.0
# 43655                             0.0                            0.0
# 43656                             0.0                            0.0
# 43657                             0.0                            0.0
#
#        building  ...  net_target-1_min_lag3  net_target-1_std_lag3  \
# 2             2  ...                 0.3982               0.119400
# 3             2  ...                 0.3884               0.023770
# 4             2  ...                 0.3880               0.003506
# 5             2  ...                 0.3877               0.000930
# 6             2  ...                 0.3887               0.004715
# ...         ...  ...                    ...                    ...
# 43653         1  ...                 0.4750               0.217000
# 43654         1  ...                 0.4410               0.209100
# 43655         1  ...                 0.4410               0.079400
# 43656         1  ...                 0.4749               0.059540
# 43657         1  ...                 0.5220               0.034970
#
#       cons_target  gen_target  cons_target-2  gen_target-2  \
# 2        0.106422    0.000000       0.170776      0.000000
# 3        0.109127    0.000000       0.116313      0.000000
# 4        0.107621    0.000000       0.106422      0.000000
# 5        0.120207    0.000000       0.109127      0.000000
# 6        0.156445   14.095833       0.107621      0.000000
# ...           ...         ...            ...           ...
# 43653    0.144716    0.000000       0.703661      2.858333
# 43654    0.335914    0.000000       0.092567      0.000000
# 43655    0.223369    0.000000       0.144716      0.000000
# 43656    0.272052    0.000000       0.335914      0.000000
# 43657    0.201491    0.000000       0.223369      0.000000
#
#        diffuse_solar_radiation+1  drybulb_temp+1  relative_humidity+1  \
# 2                       0.000000            19.4                 87.0
# 3                       0.000000            19.4                 90.0
# 4                       0.000000            18.9                 90.0
# 5                       0.000000            18.3                 93.0
# 6                       2.772589            18.9                 90.0
# ...                          ...             ...                  ...
# 43653                   0.000000            18.9                 87.0
# 43654                   0.000000            19.4                 84.0
# 43655                   0.000000            18.9                 90.0
# 43656                   0.000000            20.5                 76.0
# 43657                   0.000000            19.4                 87.0
#
#        net_target-23
# 2           0.382273
# 3           0.437649
# 4           0.418428
# 5           0.466455
# 6           0.341153
# ...              ...
# 43653       0.525154
# 43654       0.596310
# 43655       0.457615
# 43656       0.453849
# 43657       0.456758
#
# [43560 rows x 39 columns]

# %%
# run several lgb models for multiple quantiles
def run_lgb(data, datat, features, target, quantile, params, seed=42):
    # set seed
    np.random.seed(seed)
    # set params
    params['seed'] = seed
    params['metric'] = 'quantile'
    params['alpha'] = quantile
    # train test split
    train = data[data['day_year'] < 7000]
    valid = data[data['day_year'] >= 7000]
    # train
    x_train = train[features]
    y_train = train[target]
    x_valid = valid[features]
    y_valid = valid[target]
    lgb_train = lgb.Dataset(x_train, y_train)
    lgb_valid = lgb.Dataset(x_valid, y_valid)
    model = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_valid], num_boost_round=1000, early_stopping_rounds=50, verbose_eval=100)
    # save model in the model folder, with the name of the quantile
    model.save_model('models/lgb_' + str(quantile.round(3)) + '.txt')
    # predict
    x_test = datat[features]
    y_pred = model.predict(data[features], num_iteration=model.best_iteration)
    y_pred_test = model.predict(x_test, num_iteration=model.best_iteration)
    return y_pred, y_pred_test

# produce 5 quantile forecasts with uniform weights and output the dataframe with 5 columns
def run_lgb_ensemble(data, datat, features, target, params, seed=42):
    y_preds = []
    y_preds_test = []
    for quantile in qts:
        y_pred, y_pred_test = run_lgb(data, datat, features, target, quantile, params, seed)
        y_preds.append(y_pred)
        y_preds_test.append(y_pred_test)
    y_preds = np.array(y_preds).T
    y_preds_test = np.array(y_preds_test).T
    y_preds = pd.DataFrame(y_preds, columns=qts, index=data.timestamp)
    y_preds_test = pd.DataFrame(y_preds_test, columns=qts, index=datat.timestamp)
    return y_preds, y_preds_test

# %%
params = {
    'objective': 'quantile',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'bagging_fraction': 0.7,
    'bagging_freq': 1,
    'feature_fraction': 0.7,
    'verbose': -1
}
output, output_test = run_lgb_ensemble(data_train, data_test, features, target, params, seed=42)
# Out:
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.00019888	valid_1's quantile: 0.000265543
# Early stopping, best iteration is:
# [128]	training's quantile: 0.000180011	valid_1's quantile: 0.000260544
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.00559065	valid_1's quantile: 0.00751702
# Early stopping, best iteration is:
# [119]	training's quantile: 0.00543929	valid_1's quantile: 0.00748835
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.00949362	valid_1's quantile: 0.0127763
# [200]	training's quantile: 0.00885746	valid_1's quantile: 0.0126423
# Early stopping, best iteration is:
# [186]	training's quantile: 0.00889786	valid_1's quantile: 0.0126362
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0124695	valid_1's quantile: 0.0170324
# [200]	training's quantile: 0.0118041	valid_1's quantile: 0.0169228
# [300]	training's quantile: 0.0114936	valid_1's quantile: 0.0168623
# Early stopping, best iteration is:
# [291]	training's quantile: 0.0115153	valid_1's quantile: 0.0168558
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0148699	valid_1's quantile: 0.0205925
# [200]	training's quantile: 0.0141837	valid_1's quantile: 0.0204588
# Early stopping, best iteration is:
# [165]	training's quantile: 0.0143104	valid_1's quantile: 0.0204271
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0168039	valid_1's quantile: 0.0236246
# [200]	training's quantile: 0.0161459	valid_1's quantile: 0.0233666
# [300]	training's quantile: 0.0158477	valid_1's quantile: 0.0232662
# Early stopping, best iteration is:
# [311]	training's quantile: 0.0158183	valid_1's quantile: 0.0232574
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0184306	valid_1's quantile: 0.0259256
# [200]	training's quantile: 0.0177825	valid_1's quantile: 0.0255744
# Early stopping, best iteration is:
# [178]	training's quantile: 0.0178724	valid_1's quantile: 0.0255381
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.019762	valid_1's quantile: 0.0276882
# [200]	training's quantile: 0.0191454	valid_1's quantile: 0.0273887
# Early stopping, best iteration is:
# [206]	training's quantile: 0.0191278	valid_1's quantile: 0.0273764
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0208064	valid_1's quantile: 0.0291158
# [200]	training's quantile: 0.0201876	valid_1's quantile: 0.0288819
# Early stopping, best iteration is:
# [186]	training's quantile: 0.0202426	valid_1's quantile: 0.0288563
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0215472	valid_1's quantile: 0.0300308
# [200]	training's quantile: 0.0209536	valid_1's quantile: 0.0297684
# [300]	training's quantile: 0.0206277	valid_1's quantile: 0.0296902
# Early stopping, best iteration is:
# [285]	training's quantile: 0.0206825	valid_1's quantile: 0.0296817
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0219698	valid_1's quantile: 0.0306862
# [200]	training's quantile: 0.0213894	valid_1's quantile: 0.030312
# [300]	training's quantile: 0.0210571	valid_1's quantile: 0.0302127
# Early stopping, best iteration is:
# [315]	training's quantile: 0.0210107	valid_1's quantile: 0.0301856
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0221401	valid_1's quantile: 0.030807
# [200]	training's quantile: 0.0215639	valid_1's quantile: 0.0304119
# [300]	training's quantile: 0.0212249	valid_1's quantile: 0.0303106
# Early stopping, best iteration is:
# [285]	training's quantile: 0.0212713	valid_1's quantile: 0.0302917
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0220328	valid_1's quantile: 0.0305194
# [200]	training's quantile: 0.0214328	valid_1's quantile: 0.0301583
# [300]	training's quantile: 0.0211139	valid_1's quantile: 0.0301231
# Early stopping, best iteration is:
# [317]	training's quantile: 0.0210599	valid_1's quantile: 0.0301109
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0216332	valid_1's quantile: 0.0298986
# [200]	training's quantile: 0.021013	valid_1's quantile: 0.0294922
# [300]	training's quantile: 0.0206764	valid_1's quantile: 0.0294335
# Early stopping, best iteration is:
# [257]	training's quantile: 0.020804	valid_1's quantile: 0.0294125
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0209053	valid_1's quantile: 0.0288113
# [200]	training's quantile: 0.0202886	valid_1's quantile: 0.0284782
# [300]	training's quantile: 0.0199202	valid_1's quantile: 0.0284955
# Early stopping, best iteration is:
# [259]	training's quantile: 0.0200527	valid_1's quantile: 0.0284426
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0197202	valid_1's quantile: 0.0272313
# [200]	training's quantile: 0.019115	valid_1's quantile: 0.0270248
# Early stopping, best iteration is:
# [231]	training's quantile: 0.0189959	valid_1's quantile: 0.0270111
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0181155	valid_1's quantile: 0.0249195
# [200]	training's quantile: 0.017484	valid_1's quantile: 0.0247727
# Early stopping, best iteration is:
# [189]	training's quantile: 0.0175285	valid_1's quantile: 0.0247557
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0158514	valid_1's quantile: 0.021938
# [200]	training's quantile: 0.0152157	valid_1's quantile: 0.0218034
# Early stopping, best iteration is:
# [204]	training's quantile: 0.0151953	valid_1's quantile: 0.0217846
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.012702	valid_1's quantile: 0.0175826
# Early stopping, best iteration is:
# [114]	training's quantile: 0.0125755	valid_1's quantile: 0.0175577
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.00807018	valid_1's quantile: 0.0111269
# Early stopping, best iteration is:
# [78]	training's quantile: 0.00830687	valid_1's quantile: 0.0110929
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.000360573	valid_1's quantile: 0.000452969
# Early stopping, best iteration is:
# [53]	training's quantile: 0.000393745	valid_1's quantile: 0.000440299

# %%
def post_process(data):
    # sort column names
    data = data[sorted(data.columns)]
    data.columns = np.round(data.columns, 3)
    data.index = pd.to_datetime(data.index)
    data['hour'] = data.index.hour
    return data

output = post_process(output)
output_test = post_process(output_test)

# %%
output.to_csv('./data/quantile/year_qs.csv', index=True)
output_test.to_csv('./data/quantile/year_qs_test.csv', index=True)

# %%
output_test.iloc[20]
# Out:
# 0.001     0.310481
# 0.05      0.369237
# 0.1       0.380590
# 0.15      0.392508
# 0.2       0.395841
# 0.25      0.407541
# 0.3       0.410353
# 0.35      0.412127
# 0.4       0.417983
# 0.45      0.426125
# 0.5       0.424063
# 0.55      0.435589
# 0.6       0.445733
# 0.65      0.449849
# 0.7       0.472793
# 0.75      0.479409
# 0.8       0.506465
# 0.85      0.540945
# 0.9       0.601305
# 0.95      0.663160
# 0.999     0.815909
# hour     20.000000
# Name: 2021-08-02 20:00:00, dtype: float64
