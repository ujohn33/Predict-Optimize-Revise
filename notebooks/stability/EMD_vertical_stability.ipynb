# %%
import os
os.chdir(os.path.dirname(os.path.dirname(os.getcwd())))

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scienceplots

# %%
EMD_h_3 = pd.read_csv('results/EMD_mean_phase3.csv', index_col=0)
EMD_h_3 = EMD_h_3.sort_index()
EMD_h_3
# Out:
#          EMD
# 1   0.117233
# 2   0.063370
# 3   0.046229
# 4   0.038363
# 5   0.035063
# 6   0.034000
# 7   0.033114
# 8   0.031129
# 9   0.033978
# 10  0.034881
# 11  0.036166
# 12  0.039166

# %%
# set style to seaborn
plt.style.use(['science','ieee'])
# proportion 2:1
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
ax.plot(EMD_h_3.index, EMD_h_3['EMD'],  marker='s', linestyle='dotted', linewidth=5, markersize=15, color='#333333')
ax.set_xlabel('Forecast commitment $v_{F}$', fontsize=20)
ax.set_ylabel('$EMD_{V}$', fontsize=20)
# make x ticks bigger
ax.grid()
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
