# %%
import os, inspect
import sys
os.chdir(os.path.dirname(os.getcwd()))
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import scienceplots

plt.style.use('science')

# Define the function for competitive difference bound
def competitive_difference(v, A, B, a):
    return A / v + B * np.sqrt(1 - a**(2 * (v + 1)))

# Define commitment levels
v = np.linspace(1, 30, 300)

# Case 2: Deterministic
A2, B2, a2 = 0.9, 6, 0.99
cd_deterministic = competitive_difference(v, A2, B2, a2)

# Case 2: Stochastic (lower B to reflect reduced forecast penalty)
A2_s, B2_s, a2_s = A2, 5, a2
cd_stochastic = competitive_difference(v, A2_s, B2_s, a2_s)

plt.figure(figsize=(10, 6))
plt.plot(v, cd_deterministic, label=r'Deterministic ($A={}, B={}, a={}$)'.format(A2, B2, a2), color='darkblue', linewidth=2)
plt.plot(v, cd_stochastic, label=r'Stochastic ($A={}, B_s={}, a={}$)'.format(A2_s, B2_s, a2_s), color='darkblue', linestyle='--', linewidth=2)

plt.xlabel('Commitment level $v$', fontsize=20)
plt.ylabel('Expected Competitive Difference', fontsize=20)

# make x axis logarithmic
plt.xscale('log')
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Define the range of v
v = np.arange(1, 50)

# Parameters for both cases
a = 0.99
B = 6

# Case 1: Low switching cost
A1 = 0.2
cost1 = A1 / v + B * (1 - a ** (2 * (v + 1)))

# Case 2: High switching cost
A2 = 0.9
cost2 = A2 / v + B * (1 - a ** (2 * (v + 1)))

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(v, cost1, label=r'Low switching costs: $A={}, B={}, a={}$'.format(A1, B, a), color='royalblue', linewidth=2)
plt.plot(v, cost2, label=r'High switching costs: $A={}, B={}, a={}$'.format(A2, B, a), color='navy', linewidth=2)

plt.xlabel("Commitment level $v$", fontsize=18)
plt.ylabel("Expected Competitive Difference", fontsize=18)

# make x axis logarithmic
plt.xscale('log')
#plt.title("Trade-off in FHC: Switching Cost vs Forecast Error", fontsize=16)
plt.legend(fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Define the range of v
v = np.arange(1, 50)

# Parameters for both cases
A = 1
B = 6

# low correlation decay
a1 = 0.90
a2 = 0.99

cost1 = A / v + B * (1 - a1 ** (2 * (v + 1)))
cost2 = A / v + B * (1 - a2 ** (2 * (v + 1)))

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(v, cost1, label=r'Low correlation decay: $A={}, B={}, a={}$'.format(A, B, a1), color='royalblue', linewidth=2)
plt.plot(v, cost2, label=r'High correlation decay: $A={}, B={}, a={}$'.format(A, B, a2), color='navy', linewidth=2)

plt.xlabel("Commitment level $v$", fontsize=16)
plt.ylabel("Expected competitive difference", fontsize=16)

# make x axis logarithmic
plt.xscale('log')
#plt.title("Trade-off in FHC: Switching Cost vs Forecast Error", fontsize=16)
plt.legend(fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, alpha=0.7)
plt.tight_layout()
plt.show()
