# %%
import os
# Change native directory to root
os.chdir(os.path.dirname(os.getcwd()))

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb

features = ['Month', 'Hour', 'hour_x', 'hour_y', 'month_x', 'month_y',
'net_target-23', 'diffuse_solar_radiation+1', 'relative_humidity+1', 'drybulb_temp+1']
target = 'net_target'
qts = np.concatenate([[0.001],np.arange(0.05,0.951,0.05),[0.999]])
# Out:
# /Users/evgenygenov/miniforge3/envs/conformal/lib/python3.8/site-packages/dask/dataframe/backends.py:187: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# /Users/evgenygenov/miniforge3/envs/conformal/lib/python3.8/site-packages/dask/dataframe/backends.py:187: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# /Users/evgenygenov/miniforge3/envs/conformal/lib/python3.8/site-packages/dask/dataframe/backends.py:187: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %%
data_train = pd.read_csv('data/extra_train.csv', index_col=0)
data_test = pd.read_csv('data/extra_test.csv', index_col=0)
data_test
# Out:
#        Month  Hour  Day Type  cons_target-1  Solar Generation [W/kW]  \
# 17472    8.0   0.0       2.0   1.369956e-09                      0.0
# 17473    8.0   1.0       2.0   1.372561e-09                      0.0
# 17474    8.0   2.0       2.0   1.337067e-09                      0.0
# 17475    8.0   3.0       2.0   1.372887e-09                      0.0
# 17476    8.0   4.0       2.0   1.334462e-09                      0.0
# ...      ...   ...       ...            ...                      ...
# 26179    7.0  19.0       7.0   1.411440e-01                      0.0
# 26180    7.0  20.0       7.0   1.584599e-01                      0.0
# 26181    7.0  21.0       7.0   1.207468e-01                      0.0
# 26182    7.0  22.0       7.0   1.153600e-01                      0.0
# 26183    7.0  23.0       7.0   1.158353e-01                      0.0
#
#        Outdoor Drybulb Temperature [C]  Relative Humidity [%]  \
# 17472                             19.4                   87.0
# 17473                             19.4                   87.0
# 17474                             19.4                   90.0
# 17475                             18.9                   90.0
# 17476                             18.3                   93.0
# ...                                ...                    ...
# 26179                             18.3                   90.0
# 26180                             18.9                   87.0
# 26181                             19.4                   84.0
# 26182                             18.9                   90.0
# 26183                             20.5                   76.0
#
#        Diffuse Solar Radiation [W/m2]  Direct Solar Radiation [W/m2]  \
# 17472                             0.0                            0.0
# 17473                             0.0                            0.0
# 17474                             0.0                            0.0
# 17475                             0.0                            0.0
# 17476                             0.0                            0.0
# ...                               ...                            ...
# 26179                             0.0                            0.0
# 26180                             0.0                            0.0
# 26181                             0.0                            0.0
# 26182                             0.0                            0.0
# 26183                             0.0                            0.0
#
#        building  ...  net_target-1_min_lag3  net_target-1_std_lag3  \
# 17472         4  ...                 0.4092               0.000000
# 17473         4  ...                 0.4092               0.000000
# 17474         4  ...                 0.4092               0.000000
# 17475         4  ...                 0.4092               0.000000
# 17476         4  ...                 0.4092               0.000000
# ...         ...  ...                    ...                    ...
# 26179         4  ...                 0.4450               0.057770
# 26180         4  ...                 0.5210               0.014170
# 26181         4  ...                 0.5054               0.014770
# 26182         4  ...                 0.4998               0.018370
# 26183         4  ...                 0.4995               0.002333
#
#         cons_target  gen_target  cons_target-2  gen_target-2  \
# 17472  1.372561e-09    0.000000   1.943403e-09      0.000000
# 17473  1.337067e-09    0.000000   1.369956e-09      0.000000
# 17474  1.372887e-09    0.000000   1.372561e-09      0.000000
# 17475  1.334462e-09    0.000000   1.337067e-09      0.000000
# 17476  2.731689e-05    6.870833   1.372887e-09      0.000000
# ...             ...         ...            ...           ...
# 26179  1.584599e-01    0.000000   1.853529e-01     12.208333
# 26180  1.207468e-01    0.000000   1.411440e-01      0.000000
# 26181  1.153600e-01    0.000000   1.584599e-01      0.000000
# 26182  1.158353e-01    0.000000   1.207468e-01      0.000000
# 26183  7.127949e-02    0.000000   1.153600e-01      0.000000
#
#        diffuse_solar_radiation+1  drybulb_temp+1  relative_humidity+1  \
# 17472                   0.000000            19.4                 87.0
# 17473                   0.000000            19.4                 90.0
# 17474                   0.000000            18.9                 90.0
# 17475                   0.000000            18.3                 93.0
# 17476                   2.772589            18.9                 90.0
# ...                          ...             ...                  ...
# 26179                   0.000000            18.9                 87.0
# 26180                   0.000000            19.4                 84.0
# 26181                   0.000000            18.9                 90.0
# 26182                   0.000000            20.5                 76.0
# 26183                   0.000000            19.4                 87.0
#
#        net_target-23
# 17472       0.409185
# 17473       0.409185
# 17474       0.409185
# 17475       0.405686
# 17476       0.391654
# ...              ...
# 26179       0.537826
# 26180       0.525127
# 26181       0.518110
# 26182       0.491720
# 26183       0.474531
#
# [8712 rows x 39 columns]

# %%
data_test.columns
# Out:
# Index(['Month', 'Hour', 'Day Type', 'cons_target-1', 'Solar Generation [W/kW]',
#        'Outdoor Drybulb Temperature [C]', 'Relative Humidity [%]',
#        'Diffuse Solar Radiation [W/m2]', 'Direct Solar Radiation [W/m2]',
#        'building', 'day_year', 'dayinyear', 'timestamp', 'number',
#        'weekday_hour', 'hour_x', 'hour_y', 'month_x', 'month_y', 'weekday_x',
#        'weekday_y', 'net', 'net_target', 'net+1', 'cons+1', 'gen+1',
#        'net_target-1', 'net_target-1_mean_lag3', 'net_target-1_max_lag3',
#        'net_target-1_min_lag3', 'net_target-1_std_lag3', 'cons_target',
#        'gen_target', 'cons_target-2', 'gen_target-2',
#        'diffuse_solar_radiation+1', 'drybulb_temp+1', 'relative_humidity+1',
#        'net_target-23'],
#       dtype='object')

# %%
# run several lgb models for multiple quantiles
def run_lgb(data, datat, features, target, quantile, params, seed=42):
    # set seed
    np.random.seed(seed)
    # set params
    params['seed'] = seed
    params['metric'] = 'quantile'
    params['alpha'] = quantile
    # train test split
    train = data[data['day_year'] < 7000]
    valid = data[data['day_year'] >= 7000]
    # train
    x_train = train[features]
    y_train = train[target]
    x_valid = valid[features]
    y_valid = valid[target]
    lgb_train = lgb.Dataset(x_train, y_train)
    lgb_valid = lgb.Dataset(x_valid, y_valid)
    model = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_valid], num_boost_round=1000, early_stopping_rounds=50, verbose_eval=100)
    # predict
    x_test = datat[features]
    y_pred = model.predict(data[features], num_iteration=model.best_iteration)
    y_pred_test = model.predict(x_test, num_iteration=model.best_iteration)
    return y_pred, y_pred_test

# produce 5 quantile forecasts with uniform weights and output the dataframe with 5 columns
def run_lgb_ensemble(data, datat, features, target, params, seed=42):
    y_preds = []
    y_preds_test = []
    for quantile in qts:
        y_pred, y_pred_test = run_lgb(data, datat, features, target, quantile, params, seed)
        y_preds.append(y_pred)
        y_preds_test.append(y_pred_test)
    y_preds = np.array(y_preds).T
    y_preds_test = np.array(y_preds_test).T
    y_preds = pd.DataFrame(y_preds, columns=qts, index=data.timestamp)
    y_preds_test = pd.DataFrame(y_preds_test, columns=qts, index=datat.timestamp)
    return y_preds, y_preds_test

# %%
params = {
    'objective': 'quantile',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'bagging_fraction': 0.7,
    'bagging_freq': 1,
    'feature_fraction': 0.7,
    'verbose': -1
}
output, output_test = run_lgb_ensemble(data_train, data_test, features, target, params, seed=42)
# Out:
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.000194511	valid_1's quantile: 0.000232015
# Early stopping, best iteration is:
# [129]	training's quantile: 0.000185443	valid_1's quantile: 0.000230922
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.00638442	valid_1's quantile: 0.00866804
# Early stopping, best iteration is:
# [94]	training's quantile: 0.00641947	valid_1's quantile: 0.00866339
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0112885	valid_1's quantile: 0.01565
# Early stopping, best iteration is:
# [138]	training's quantile: 0.0109655	valid_1's quantile: 0.0156088
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0152429	valid_1's quantile: 0.0217923
# [200]	training's quantile: 0.0146178	valid_1's quantile: 0.0215848
# Early stopping, best iteration is:
# [223]	training's quantile: 0.0145099	valid_1's quantile: 0.0215659
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0185785	valid_1's quantile: 0.027078
# [200]	training's quantile: 0.0178567	valid_1's quantile: 0.0268752
# [300]	training's quantile: 0.0173913	valid_1's quantile: 0.0267902
# Early stopping, best iteration is:
# [291]	training's quantile: 0.0174293	valid_1's quantile: 0.0267875
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0213562	valid_1's quantile: 0.0311372
# [200]	training's quantile: 0.0205636	valid_1's quantile: 0.0311101
# [300]	training's quantile: 0.0200756	valid_1's quantile: 0.0310611
# Early stopping, best iteration is:
# [251]	training's quantile: 0.0203059	valid_1's quantile: 0.0310224
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0236169	valid_1's quantile: 0.0346851
# Early stopping, best iteration is:
# [124]	training's quantile: 0.0233723	valid_1's quantile: 0.0346351
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0254579	valid_1's quantile: 0.0370854
# Early stopping, best iteration is:
# [124]	training's quantile: 0.0251862	valid_1's quantile: 0.0369549
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0269006	valid_1's quantile: 0.03976
# Early stopping, best iteration is:
# [108]	training's quantile: 0.0268059	valid_1's quantile: 0.0396794
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0279713	valid_1's quantile: 0.0415981
# Early stopping, best iteration is:
# [123]	training's quantile: 0.0276983	valid_1's quantile: 0.0414266
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0286686	valid_1's quantile: 0.0425782
# Early stopping, best iteration is:
# [123]	training's quantile: 0.0283632	valid_1's quantile: 0.0424955
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.028934	valid_1's quantile: 0.0428915
# Early stopping, best iteration is:
# [123]	training's quantile: 0.0286616	valid_1's quantile: 0.0427811
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0286825	valid_1's quantile: 0.0433822
# [200]	training's quantile: 0.0276962	valid_1's quantile: 0.0433627
# Early stopping, best iteration is:
# [154]	training's quantile: 0.0281121	valid_1's quantile: 0.0431393
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0280981	valid_1's quantile: 0.0426075
# [200]	training's quantile: 0.0271062	valid_1's quantile: 0.0425198
# Early stopping, best iteration is:
# [183]	training's quantile: 0.0272472	valid_1's quantile: 0.0424637
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0269148	valid_1's quantile: 0.0409183
# Early stopping, best iteration is:
# [107]	training's quantile: 0.0268323	valid_1's quantile: 0.0408181
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0252318	valid_1's quantile: 0.0381742
# [200]	training's quantile: 0.0241605	valid_1's quantile: 0.0378641
# Early stopping, best iteration is:
# [210]	training's quantile: 0.0240758	valid_1's quantile: 0.0378058
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0228314	valid_1's quantile: 0.0345123
# [200]	training's quantile: 0.0217256	valid_1's quantile: 0.0343464
# Early stopping, best iteration is:
# [186]	training's quantile: 0.0218529	valid_1's quantile: 0.0342518
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0194874	valid_1's quantile: 0.0299673
# [200]	training's quantile: 0.0185109	valid_1's quantile: 0.029937
# Early stopping, best iteration is:
# [157]	training's quantile: 0.0188692	valid_1's quantile: 0.0298405
# Training until validation scores don't improve for 50 rounds
# [100]	training's quantile: 0.0151319	valid_1's quantile: 0.0238053
# Early stopping, best iteration is:
# [117]	training's quantile: 0.0149158	valid_1's quantile: 0.0237043
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's quantile: 0.0105824	valid_1's quantile: 0.0149228
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's quantile: 0.000478571	valid_1's quantile: 0.000546904

# %%
def post_process(data):
    # sort column names
    data = data[sorted(data.columns)]
    data.columns = np.round(data.columns, 3)
    data.index = pd.to_datetime(data.index)
    data['hour'] = data.index.hour
    return data

output = post_process(output)
output_test = post_process(output_test)

# %%
output.to_csv('./data/quantile/year_qs.csv', index=True)
output_test.to_csv('./data/quantile/year_qs_test.csv', index=True)

# %%
output_test
# Out:
#                         0.001      0.05       0.1      0.15       0.2  \
# timestamp
# 2021-08-01 22:00:00  0.320683  0.368781  0.381283  0.397807  0.416420
# 2021-08-01 23:00:00  0.328759  0.369254  0.377965  0.391575  0.401106
# 2021-08-02 00:00:00  0.301606  0.366134  0.373308  0.383290  0.395295
# 2021-08-02 01:00:00  0.301606  0.364939  0.371483  0.379608  0.387677
# 2021-08-02 02:00:00  0.304875  0.365058  0.371539  0.379511  0.382475
# ...                       ...       ...       ...       ...       ...
# 2022-07-31 17:00:00  0.267956  0.363932  0.388768  0.398471  0.407761
# 2022-07-31 18:00:00  0.288000  0.381748  0.389868  0.402354  0.401551
# 2022-07-31 19:00:00  0.305377  0.379938  0.390698  0.400881  0.402097
